# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
dframe = DataFrame({'k1': ['X','X','Y','Y','Z'],
                    'k2': ['alpha','beta','alpha','beta','alpha'],
                   'dataset1': np.random.randn(5),
                   'dataset2': np.random.randn(5)})

# %%
dframe
# Out:
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
# 1  0.778758 -1.133728  X   beta
# 2  1.167633  0.943766  Y  alpha
# 3 -0.546766 -0.808054  Y   beta
# 4  0.998442 -1.356312  Z  alpha

# %%
group1 = dframe['dataset1'].groupby(dframe['k1'])

# %%
group1

# %%
group1.mean()
# Out:
# k1
# X    1.036825
# Y    0.310433
# Z    0.998442
# Name: dataset1, dtype: float64

# %%
cities = np.array(['NY', 'LA', 'LA', 'NY', 'NY'])
month = np.array(['JAN', 'FEB', 'JAN', 'FEB', 'JAN'])

# %%
dframe
# Out:
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
# 1  0.778758 -1.133728  X   beta
# 2  1.167633  0.943766  Y  alpha
# 3 -0.546766 -0.808054  Y   beta
# 4  0.998442 -1.356312  Z  alpha

# %%
dframe['dataset1'].groupby([cities, month]).mean()
# Out:
# LA  FEB    0.778758
#     JAN    1.167633
# NY  FEB   -0.546766
#     JAN    1.146667
# Name: dataset1, dtype: float64

# %%
dframe.groupby('k1').mean()
# Out:
#     dataset1  dataset2
# k1
# X   1.036825 -0.132052
# Y   0.310433  0.067856
# Z   0.998442 -1.356312

# %%
dframe.groupby(['k1', 'k2']).mean()
# Out:
#           dataset1  dataset2
# k1 k2
# X  alpha  1.294892  0.869625
#    beta   0.778758 -1.133728
# Y  alpha  1.167633  0.943766
#    beta  -0.546766 -0.808054
# Z  alpha  0.998442 -1.356312

# %%
dataset2_group = dframe.groupby(['k1', 'k2'])[['dataset2']]

# %%
dataset2_group.mean()
# Out:
#           dataset2
# k1 k2
# X  alpha  0.869625
#    beta  -1.133728
# Y  alpha  0.943766
#    beta  -0.808054
# Z  alpha -1.356312

# %%
dframe.groupby(['k1']).size()
# Out:
# k1
# X    2
# Y    2
# Z    1
# dtype: int64

# %%
for name, group in dframe.groupby('k1'):
    print('This is the {} group'.format(name))
    print(group)
    print('\n')
# Out:
# This is the X group
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
# 1  0.778758 -1.133728  X   beta
#
#
# This is the Y group
#    dataset1  dataset2 k1     k2
# 2  1.167633  0.943766  Y  alpha
# 3 -0.546766 -0.808054  Y   beta
#
#
# This is the Z group
#    dataset1  dataset2 k1     k2
# 4  0.998442 -1.356312  Z  alpha

# %%
for (k1,k2), group in dframe.groupby(['k1', 'k2']):
    print('Key1={} Key2={}'.format(k1, k2))
    print(group)
    print('\n')
# Out:
# Key1=X Key2=alpha
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
#
#
# Key1=X Key2=beta
#    dataset1  dataset2 k1    k2
# 1  0.778758 -1.133728  X  beta
#
#
# Key1=Y Key2=alpha
#    dataset1  dataset2 k1     k2
# 2  1.167633  0.943766  Y  alpha
#
#
# Key1=Y Key2=beta
#    dataset1  dataset2 k1    k2
# 3 -0.546766 -0.808054  Y  beta
#
#
# Key1=Z Key2=alpha
#    dataset1  dataset2 k1     k2
# 4  0.998442 -1.356312  Z  alpha

# %%
gr = dframe.groupby('k1')

# %%
gr.get_group('X')
# Out:
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
# 1  0.778758 -1.133728  X   beta

# %%
group_dict = dict(list(dframe.groupby('k1')))

# %%
group_dict['X']
# Out:
#    dataset1  dataset2 k1     k2
# 0  1.294892  0.869625  X  alpha
# 1  0.778758 -1.133728  X   beta

# %%
group_dict_axis1 = dict(list(dframe.groupby(dframe.dtypes, axis=1)))

# %%
group_dict_axis1
# Out:
# {dtype('float64'):    dataset1  dataset2
#  0  1.294892  0.869625
#  1  0.778758 -1.133728
#  2  1.167633  0.943766
#  3 -0.546766 -0.808054
#  4  0.998442 -1.356312, dtype('O'):   k1     k2
#  0  X  alpha
#  1  X   beta
#  2  Y  alpha
#  3  Y   beta
#  4  Z  alpha}
