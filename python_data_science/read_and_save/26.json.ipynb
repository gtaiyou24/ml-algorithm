# %%
json_obj = """
{
  "zoo_animal": "Lion",
  "food": ["Meat", "Veggies", "Honey"],
  "fur": "Golden",
  "clothes": null,
  "diet": [{"zoo_animal": "Gazelle", "food": "grass", "fur": "Brown"}]
}
"""

# %%
import json

# %%
data = json.loads(json_obj)

# %%
data
# Out:
# {'clothes': None,
#  'diet': [{'food': 'grass', 'fur': 'Brown', 'zoo_animal': 'Gazelle'}],
#  'food': ['Meat', 'Veggies', 'Honey'],
#  'fur': 'Golden',
#  'zoo_animal': 'Lion'}

# %%
type(data)
# Out:
# dict

# %%
data['diet']
# Out:
# [{'food': 'grass', 'fur': 'Brown', 'zoo_animal': 'Gazelle'}]

# %%
json.dumps(data)
# Out:
# '{"zoo_animal": "Lion", "food": ["Meat", "Veggies", "Honey"], "diet": [{"zoo_animal": "Gazelle", "food": "grass", "fur": "Brown"}], "clothes": null, "fur": "Golden"}'

# %%
json.dump(data, open('data.json', 'w'))

# %%
# !cat data.json
# Out:
# {"zoo_animal": "Lion", "food": ["Meat", "Veggies", "Honey"], "diet": [{"zoo_animal": "Gazelle", "food": "grass", "fur": "Brown"}], "clothes": null, "fur": "Golden"}

# %%
json.load(open('data.json'))
# Out:
# {'clothes': None,
#  'diet': [{'food': 'grass', 'fur': 'Brown', 'zoo_animal': 'Gazelle'}],
#  'food': ['Meat', 'Veggies', 'Honey'],
#  'fur': 'Golden',
#  'zoo_animal': 'Lion'}
