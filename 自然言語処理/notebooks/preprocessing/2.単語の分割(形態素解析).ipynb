# %% [markdown]
# # 単語の分割(形態素解析)
#
# ## 参考資料
#
#  - https://qiita.com/Hironsan/items/2466fe0f344115aff177#%E5%8D%98%E8%AA%9E%E3%81%AE%E5%88%86%E5%89%B2
#  - https://github.com/Hironsan/natural-language-preprocessings/blob/master/preprocessings/ja/tokenizer.py

# %%
import os
import re
import sys


pwd = os.getcwd()
path = re.search('.+/自然言語処理', pwd).group(0)

sys.path.append(path)
print(sys.path)
# Out:
# ['', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python36.zip', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/lib-dynload', '/Users/taiyou/.local/lib/python3.6/site-packages', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/aeosa', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/sklearn_contrib_py_earth-0.1.0-py3.6-macosx-10.7-x86_64.egg', '/Users/taiyou/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/IPython/extensions', '/Users/taiyou/.ipython', '/Users/taiyou/Desktop/machine-learning/自然言語処理']

# %%
from src.preprocessings.tokenizer import MeCabTokenizer

# %%
scouty_text = """
scoutyでは、退職率予測アルゴリズム・企業と候補者の最適なマッチング発見アルゴリズムなどの開発をマネージし、ビジネス上の問題解決につながるアルゴリズム開発のマネジメントを行なう「アルゴリズムマネージャ」のポジションを募集しています。

アルゴリズムマネージャの詳細情報はこちら： http://ai-lab.scouty.co.jp/entry/2017/12/13/1230

★Point1：90万人のオープンデータ解析に挑戦！ 
scoutyではWEB上のSNSデータを中心に「人」に関するデータをクロールして集め、約90万人（2017年12月時点）のデータベースを作りました。 
scoutyのアルゴリズムは、人々の経歴・Twitterのつぶやき・参加イベント情報・GitHubでのコード内容・ブログの記事のデータを解析して、その人に一番マッチした企業とその人が次に退職しそうな時期を予測します。こういったアルゴリズムの仕様を定めるだけでなく、開発のマイルストンや事前リサーチ、技術選定を行い、アルゴリズム開発を通じてビジネスの問題を解決に導くアルゴリズムマネージャを募集しています。

★Point2：アルゴリズムのプロダクトマネージャとなり、開発チームを率いてアルゴリズムのオーナーになれる！ 
アルゴリズムマネージャは、いわばアルゴリズムのプロダクトマネージャです。顧客のニーズをつかみ、ビジネスとアルゴリズムの接点を探り、開発のマイルストーンを定め、設計の指針をつくることができます。また、アルゴリズムマネージャはまだ認知度も低く、必要性も認知されていないので、イベント登壇やブログ記事の発信を通じて、アルゴリズムマネージャのロールモデルを作っていける方を募集しています。

◎業務内容 
・scoutyの機械学習アルゴリズム（転職可能性予測アルゴリズム、マッチングアルゴリズム等）の開発の進行・マネジメント 
・アルゴリズムがそもそもどうどのようにKGIに影響するか？というシステムダイナミクスの構築 
・アルゴリズムのメトリクス（評価指標）の設計 
・アルゴリズム構築の前の事前リサーチ 
・アルゴリズム開発のマイルストーン設定とスケジューリング 
・アルゴリズムに用いる技術選定・エンジニアとのディスカッション 
・（開発の状況とフェーズによって）アルゴリズムの実開発の一部

◎歓迎する経験・スキル 
・各データ解析手法に関しての広い知識 
・AI / ML系のライブラリ・クラウドサービスなどの広い知識（実装しなくて済む部分と実装が必要な部分の理解） 
・CRISP-DM などのデータ分析のプロセスモデルへの理解 
・ クライアント・ユーザとの対話能力 
・経営や事業上のKPIへの理解 
・実装するエンジニアのマネジメント能力 
・Pythonでの開発経験 
・Jupyter Notebookの使用経験
"""

# %% [markdown]
# 文書ソース：https://www.wantedly.com/projects/174695?ql=gaJpZM4AZkqk

# %%
mecab_tokenizer = MeCabTokenizer('/usr/local/lib/mecab/dic/mecab-ipadic-neologd')

print(mecab_tokenizer.wakati(scouty_text))
# Out:
# ['scouty', 'で', 'は', '、', '退職', '率', '予測', 'アルゴリズム', '・', '企業', 'と', '候補者', 'の', '最適', 'な', 'マッチング', '発見', 'アルゴリズム', 'など', 'の', '開発', 'を', 'マネージ', 'し', '、', 'ビジネス', '上', 'の', '問題解決', 'に', 'つながる', 'アルゴリズム', '開発', 'の', 'マネジメント', 'を', '行なう', '「', 'アルゴリズム', 'マネージャ', '」', 'の', 'ポジション', 'を', '募集', 'し', 'て', 'い', 'ます', '。', 'アルゴリズム', 'マネージャ', 'の', '詳細', '情報', 'は', 'こちら', '：', 'http://', 'ai', '-', 'lab.', 'scouty', '.', 'co.jp', '/', 'entry', '/', '2017', '/', '12', '/', '13', '/', '1230', '★', 'Point', '1', '：', '90万人', 'の', 'オープンデータ', '解析', 'に', '挑戦', '！', 'scouty', 'で', 'は', 'WEB', '上', 'の', 'SNS', 'データ', 'を', '中心', 'に', '「', '人', '」', 'に関する', 'データ', 'を', 'クロール', 'し', 'て', '集め', '、', '約', '90万人', '（', '2017年', '12月', '時点', '）', 'の', 'データベース', 'を', '作りました', '。', 'scouty', 'の', 'アルゴリズム', 'は', '、', '人々', 'の', '経歴', '・', 'Twitter', 'の', 'つぶやき', '・', '参加', 'イベント情報', '・', 'GitHub', 'で', 'の', 'コード', '内容', '・', 'ブログ', 'の', '記事', 'の', 'データ', 'を', '解析', 'し', 'て', '、', 'その', '人', 'に', '一番', 'マッチ', 'し', 'た', '企業', 'と', 'その', '人', 'が', '次に', '退職', 'し', 'そう', 'な', '時期', 'を', '予測', 'し', 'ます', '。', 'こう', 'いっ', 'た', 'アルゴリズム', 'の', '仕様', 'を', '定める', 'だけ', 'で', 'なく', '、', '開発', 'の', 'マイルストン', 'や', '事前', 'リサーチ', '、', '技術', '選定', 'を', '行い', '、', 'アルゴリズム', '開発', 'を通じて', 'ビジネス', 'の', '問題', 'を', '解決', 'に', '導く', 'アルゴリズム', 'マネージャ', 'を', '募集', 'し', 'て', 'い', 'ます', '。', '★', 'Point', '2', '：', 'アルゴリズム', 'の', 'プロダクト', 'マネージャ', 'と', 'なり', '、', '開発チーム', 'を', '率い', 'て', 'アルゴリズム', 'の', 'オーナー', 'に', 'なれる', '！', 'アルゴリズム', 'マネージャ', 'は', '、', 'いわば', 'アルゴリズム', 'の', 'プロダクト', 'マネージャ', 'です', '。', '顧客', 'の', 'ニーズ', 'を', 'つかみ', '、', 'ビジネス', 'と', 'アルゴリズム', 'の', '接点', 'を', '探り', '、', '開発', 'の', 'マイルストーン', 'を', '定め', '、', '設計', 'の', '指針', 'を', 'つくる', 'こと', 'が', 'でき', 'ます', '。', 'また', '、', 'アルゴリズム', 'マネージャ', 'は', 'まだ', '認知度', 'も', '低く', '、', '必要性', 'も', '認知', 'さ', 'れ', 'て', 'い', 'ない', 'ので', '、', 'イベント', '登壇', 'や', 'ブログ記事', 'の', '発信', 'を通じて', '、', 'アルゴリズム', 'マネージャ', 'の', 'ロールモデル', 'を', '作っ', 'て', 'いける', '方', 'を', '募集', 'し', 'て', 'い', 'ます', '。', '◎', '業務', '内容', '・', 'scouty', 'の', '機械学習', 'アルゴリズム', '（', '転職', '可能性', '予測', 'アルゴリズム', '、', 'マッチング', 'アルゴリズム', '等', '）', 'の', '開発', 'の', '進行', '・', 'マネジメント', '・', 'アルゴリズム', 'が', 'そもそも', 'どう', 'どの', 'よう', 'に', 'KGI', 'に', '影響', 'する', 'か', '？', 'という', 'システムダイナミクス', 'の', '構築', '・', 'アルゴリズム', 'の', 'メトリクス', '（', '評価', '指標', '）', 'の', '設計', '・', 'アルゴリズム', '構築', 'の', '前', 'の', '事前', 'リサーチ', '・', 'アルゴリズム', '開発', 'の', 'マイルストーン', '設定', 'と', 'スケジューリング', '・', 'アルゴリズム', 'に', '用いる', '技術', '選定', '・', 'エンジニア', 'と', 'の', 'ディスカッション', '・', '（', '開発', 'の', '状況', 'と', 'フェーズ', 'によって', '）', 'アルゴリズム', 'の', '実', '開発', 'の', '一部', '◎', '歓迎', 'する', '経験', '・', 'スキル', '・', '各', 'データ', '解析', '手法', 'に関して', 'の', '広い', '知識', '・', 'AI', '/', 'ML', '系', 'の', 'ライブラリ', '・', 'クラウド', 'サービス', 'など', 'の', '広い', '知識', '（', '実装', 'し', 'なく', 'て', '済む', '部分', 'と', '実装', 'が', '必要', 'な', '部分', 'の', '理解', '）', '・', 'CRI', 'SP-D', 'M', 'など', 'の', 'データ', '分析', 'の', 'プロセスモデル', 'へ', 'の', '理解', '・', 'クライアント', '・', 'ユーザ', 'と', 'の', '対話', '能力', '・', '経営', 'や', '事業', '上', 'の', 'KPI', 'へ', 'の', '理解', '・', '実装', 'する', 'エンジニア', 'の', 'マネジメント', '能力', '・', 'Python', 'で', 'の', '開発', '経験', '・', 'Jupyter Notebook', 'の', '使用', '経験']

# %%
print(mecab_tokenizer.wakati_baseform(scouty_text))
# Out:
# ['scouty', 'で', 'は', '、', '退職', '率', '予測', 'アルゴリズム', '・', '企業', 'と', '候補者', 'の', '最適', 'だ', 'マッチング', '発見', 'アルゴリズム', 'など', 'の', '開発', 'を', 'マネージ', 'する', '、', 'ビジネス', '上', 'の', '問題解決', 'に', 'つながる', 'アルゴリズム', '開発', 'の', 'マネジメント', 'を', '行なう', '「', 'アルゴリズム', 'マネージャ', '」', 'の', 'ポジション', 'を', '募集', 'する', 'て', 'いる', 'ます', '。', 'アルゴリズム', 'マネージャ', 'の', '詳細', '情報', 'は', 'こちら', '：', 'http://', 'AI', '-', 'lab.', 'scouty', '.', 'co.jp', '/', 'entry', '/', '2017', '/', '12', '/', '13', '/', '1230', '★', 'Point', '1', '：', '90万人', 'の', 'オープンデータ', '解析', 'に', '挑戦', '！', 'scouty', 'で', 'は', 'WEB', '上', 'の', 'SNS', 'データ', 'を', '中心', 'に', '「', '人', '」', 'に関する', 'データ', 'を', 'クロール', 'する', 'て', '集める', '、', '約', '90万人', '（', '2017年', '12月', '時点', '）', 'の', 'データベース', 'を', '作りました', '。', 'scouty', 'の', 'アルゴリズム', 'は', '、', '人々', 'の', '経歴', '・', 'Twitter', 'の', 'つぶやき', '・', '参加', 'イベント情報', '・', 'GitHub', 'で', 'の', 'コード', '内容', '・', 'blog', 'の', '記事', 'の', 'データ', 'を', '解析', 'する', 'て', '、', 'その', '人', 'に', '一番', 'マッチ', 'する', 'た', '企業', 'と', 'その', '人', 'が', '次に', '退職', 'する', 'そう', 'だ', '時期', 'を', '予測', 'する', 'ます', '。', 'こう', 'いう', 'た', 'アルゴリズム', 'の', '仕様', 'を', '定める', 'だけ', 'だ', 'ない', '、', '開発', 'の', 'マイルストン', 'や', '事前', 'リサーチ', '、', '技術', '選定', 'を', '行う', '、', 'アルゴリズム', '開発', 'を通じて', 'ビジネス', 'の', '問題', 'を', '解決', 'に', '導く', 'アルゴリズム', 'マネージャ', 'を', '募集', 'する', 'て', 'いる', 'ます', '。', '★', 'Point', '2', '：', 'アルゴリズム', 'の', 'プロダクト', 'マネージャ', 'と', 'なる', '、', '開発チーム', 'を', '率いる', 'て', 'アルゴリズム', 'の', 'オーナー', 'に', 'なれる', '！', 'アルゴリズム', 'マネージャ', 'は', '、', 'いわば', 'アルゴリズム', 'の', 'プロダクト', 'マネージャ', 'です', '。', '顧客', 'の', 'ニーズ', 'を', 'つかむ', '、', 'ビジネス', 'と', 'アルゴリズム', 'の', '接点', 'を', '探る', '、', '開発', 'の', 'Milestone', 'を', '定める', '、', '設計', 'の', '指針', 'を', 'つくる', 'こと', 'が', 'できる', 'ます', '。', 'また', '、', 'アルゴリズム', 'マネージャ', 'は', 'まだ', '認知度', 'も', '低い', '、', '必要性', 'も', '認知', 'する', 'れる', 'て', 'いる', 'ない', 'ので', '、', 'イベント', '登壇', 'や', 'ブログ記事', 'の', '発信', 'を通じて', '、', 'アルゴリズム', 'マネージャ', 'の', 'ロールモデル', 'を', '作る', 'て', 'いける', '方', 'を', '募集', 'する', 'て', 'いる', 'ます', '。', '◎', '業務', '内容', '・', 'scouty', 'の', '機械学習', 'アルゴリズム', '（', '転職', '可能性', '予測', 'アルゴリズム', '、', 'マッチング', 'アルゴリズム', '等', '）', 'の', '開発', 'の', '進行', '・', 'マネジメント', '・', 'アルゴリズム', 'が', 'そもそも', 'どう', 'どの', 'よう', 'に', 'KGI', 'に', '影響', 'する', 'か', '？', 'という', 'システムダイナミクス', 'の', '構築', '・', 'アルゴリズム', 'の', 'メトリクス', '（', '評価', '指標', '）', 'の', '設計', '・', 'アルゴリズム', '構築', 'の', '前', 'の', '事前', 'リサーチ', '・', 'アルゴリズム', '開発', 'の', 'Milestone', '設定', 'と', 'スケジューリング', '・', 'アルゴリズム', 'に', '用いる', '技術', '選定', '・', 'エンジニア', 'と', 'の', 'ディスカッション', '・', '（', '開発', 'の', '状況', 'と', 'フェーズ', 'によって', '）', 'アルゴリズム', 'の', '実', '開発', 'の', '一部', '◎', '歓迎', 'する', '経験', '・', 'スキル', '・', '各', 'データ', '解析', '手法', 'に関して', 'の', '広い', '知識', '・', 'AI', '/', 'ML', '系', 'の', 'ライブラリ', '・', 'CROWD', 'サービス', 'など', 'の', '広い', '知識', '（', '実装', 'する', 'ない', 'て', '済む', '部分', 'と', '実装', 'が', '必要', 'だ', '部分', 'の', '理解', '）', '・', 'CRI', 'SP-D', 'M', 'など', 'の', 'データ', '分析', 'の', 'プロセスモデル', 'へ', 'の', '理解', '・', 'client', '・', 'ユーザ', 'と', 'の', '対話', '能力', '・', '経営', 'や', '事業', '上', 'の', 'KPI', 'へ', 'の', '理解', '・', '実装', 'する', 'エンジニア', 'の', 'マネジメント', '能力', '・', 'Python', 'で', 'の', '開発', '経験', '・', 'Jupyter Notebook', 'の', '使用', '経験']

# %%
print(mecab_tokenizer.filter_by_pos(scouty_text, ('名詞', '動詞', '形容詞')))
# Out:
# [Token(surface='scouty', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='*', reading='', phonetic=''), Token(surface='退職', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='退職', reading='タイショク', phonetic='タイショク'), Token(surface='率', pos='名詞', pos_detail1='接尾', pos_detail2='一般', pos_detail3='*', infl_type='*', infl_form='*', base_form='率', reading='リツ', phonetic='リツ'), Token(surface='予測', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='予測', reading='ヨソク', phonetic='ヨソク'), Token(surface='アルゴリズム', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='アルゴリズム', reading='アルゴリズム', phonetic='アルゴリズム'), Token(surface='企業', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='企業', reading='キギョウ', phonetic='キギョー'), Token(surface='候補者', pos='名詞', pos_detail1='固有名詞', pos_detail2='一般', pos_detail3='*', infl_type='*', infl_form='*', base_form='候補者', reading='コウホシャ', phonetic='コーホシャ'), Token(surface='最適', pos='名詞', pos_detail1='形容動詞語幹', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='最適', reading='サイテキ', phonetic='サイテキ'), Token(surface='マッチング', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='マッチング', reading='マッチング', phonetic='マッチング'), Token(surface='発見', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='発見', reading='ハッケン', phonetic='ハッケン'), Token(surface='アルゴリズム', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='アルゴリズム', reading='アルゴリズム', phonetic='アルゴリズム'), Token(surface='開発', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='開発', reading='カイハツ', phonetic='カイハツ'), Token(surface='マネージ', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='*', reading='', phonetic=''), Token(surface='し', pos='動詞', pos_detail1='自立', pos_detail2='*', pos_detail3='*', infl_type='サ変・スル', infl_form='連用形', base_form='する', reading='シ', phonetic='シ'), Token(surface='ビジネス', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='ビジネス', reading='ビジネス', phonetic='ビジネス'), Token(surface='上', pos='名詞', pos_detail1='接尾', pos_detail2='副詞可能', pos_detail3='*', infl_type='*', infl_form='*', base_form='上', reading='ジョウ', phonetic='ジョー'), Token(surface='問題解決', pos='名詞', pos_detail1='固有名詞', pos_detail2='一般', pos_detail3='*', infl_type='*', infl_form='*', base_form='問題解決', reading='モンダイカイケツ', phonetic='モンダイカイケツ'), Token(surface='つながる', pos='動詞', pos_detail1='自立', pos_detail2='*', pos_detail3='*', infl_type='五段・ラ行', infl_form='基本形', base_form='つながる', reading='ツナガル', phonetic='ツナガル'), Token(surface='アルゴリズム', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='アルゴリズム', reading='アルゴリズム', phonetic='アルゴリズム'), Token(surface='開発', pos='名詞', pos_detail1='サ変接続', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='開発', reading='カイハツ', phonetic='カイハツ'), Token(surface='マネジメント', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='マネジメント', reading='マネジメント', phonetic='マネジメント'), Token(surface='行なう', pos='動詞', pos_detail1='自立', pos_detail2='*', pos_detail3='*', infl_type='五段・ワ行促音便', infl_form='基本形', base_form='行なう', reading='オコナウ', phonetic='オコナウ'), Token(surface='アルゴリズム', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='アルゴリズム', reading='アルゴリズム', phonetic='アルゴリズム'), Token(surface='マネージャ', pos='名詞', pos_detail1='一般', pos_detail2='*', pos_detail3='*', infl_type='*', infl_form='*', base_form='マネージャ', reading='マネージャ', phonetic=' ...
